# %%
from read_qap_log import read_loss_curves_from_json, plot_loss_curves_for_run, plot_average_loss_curves_across_problems, get_average_loss_curves_across_problems

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#baseline
results = read_loss_curves_from_json('log/loss_curves_pgd+k+3_synthetic_None_random_20250806_102220.json')
plot_average_loss_curves_across_problems(results, normalize=False)
# Out:
# Summary across 5 problems, 5 best runs:
#   - Best average hard loss: 87551100.8000
#   - Final average soft loss: 87638534.4000
#   - Final average hard loss: 87551100.8000
#   - Problems included: qap_n1000_geo_id4.dat, qap_n1000_geo_id1.dat, qap_n1000_geo_id3.dat, qap_n1000_geo_id2.dat, qap_n1000_geo_id0.dat

# %%
#baseline
results = read_loss_curves_from_json('train_be/loss_curves_pgd+k+5_synthetic_None_constant_20250805_130438.json')
plot_average_loss_curves_across_problems(results, normalize=False)
# Out:
# Summary across 5 problems, 5 best runs:
#   - Best average hard loss: 98453686.4000
#   - Final average soft loss: 98580608.0000
#   - Final average hard loss: 98453686.4000
#   - Problems included: qap_n1000_geo_id4.dat, qap_n1000_geo_id1.dat, qap_n1000_geo_id3.dat, qap_n1000_geo_id2.dat, qap_n1000_geo_id0.dat

# %%
#k comparison
results = read_loss_curves_from_json('train_be/loss_curves_pgd+k+10_real_None_random_20250730_013853.json')
plot_average_loss_curves_across_problems(results, normalize=False)
# Out:
# Summary across 8 problems, 8 best runs:
#   - Best average hard loss: 5624319.3750
#   - Final average soft loss: 5626788.3125
#   - Final average hard loss: 5624319.3750
#   - Problems included: bur26b.dat, bur26h.dat, bur26c.dat, bur26a.dat, bur26f.dat, bur26d.dat, bur26e.dat, bur26g.dat

# %%
#k comparison
results = read_loss_curves_from_json('train_be/loss_curves_pgd+k+15_real_None_random_20250730_014112.json')
plot_average_loss_curves_across_problems(results, normalize=False)
# Out:
# Summary across 8 problems, 8 best runs:
#   - Best average hard loss: 5638790.1250
#   - Final average soft loss: 5644885.0625
#   - Final average hard loss: 5638790.1250
#   - Problems included: bur26b.dat, bur26h.dat, bur26c.dat, bur26a.dat, bur26f.dat, bur26d.dat, bur26e.dat, bur26g.dat

# %%
#k comparison
results = read_loss_curves_from_json('train_be/loss_curves_pgd+k+20_real_None_random_20250730_014325.json')
plot_average_loss_curves_across_problems(results, normalize=False)
# Out:
# Summary across 8 problems, 8 best runs:
#   - Best average hard loss: 5645489.7500
#   - Final average soft loss: 5658996.0000
#   - Final average hard loss: 5645489.7500
#   - Problems included: bur26b.dat, bur26h.dat, bur26c.dat, bur26a.dat, bur26f.dat, bur26d.dat, bur26e.dat, bur26g.dat

# %%
#k comparison
results = read_loss_curves_from_json('train_be/loss_curves_pgd+k+5_real_5_random_20250730_013526.json')
plot_average_loss_curves_across_problems(results, normalize=False)
# Out:
# Summary across 8 problems, 8 best runs:
#   - Best average hard loss: 5615976.5000
#   - Final average soft loss: 5616304.4375
#   - Final average hard loss: 5615976.5000
#   - Problems included: bur26b.dat, bur26h.dat, bur26c.dat, bur26a.dat, bur26f.dat, bur26d.dat, bur26e.dat, bur26g.dat

# %%
#k comparison
results = read_loss_curves_from_json('train_be/loss_curves_pgd+k+5_real_10_random_20250730_013730.json')
plot_average_loss_curves_across_problems(results, normalize=False)
# Out:
# Summary across 8 problems, 8 best runs:
#   - Best average hard loss: 5620756.1250
#   - Final average soft loss: 5621098.3125
#   - Final average hard loss: 5620756.1250
#   - Problems included: bur26b.dat, bur26h.dat, bur26c.dat, bur26a.dat, bur26f.dat, bur26d.dat, bur26e.dat, bur26g.dat

# %%
results = read_loss_curves_from_json('train_be/loss_curves_pgd+k+5_real_20_random_20250730_013933.json')
plot_average_loss_curves_across_problems(results, normalize=False)
# Out:
# Summary across 8 problems, 8 best runs:
#   - Best average hard loss: 5613371.6250
#   - Final average soft loss: 5613769.4688
#   - Final average hard loss: 5613371.6250
#   - Problems included: bur26b.dat, bur26h.dat, bur26c.dat, bur26a.dat, bur26f.dat, bur26d.dat, bur26e.dat, bur26g.dat

# %%
results = read_loss_curves_from_json('train_be/loss_curves_pgd+k+5_real_50_random_20250730_014137.json')
plot_average_loss_curves_across_problems(results, normalize=False)
# Out:
# Summary across 8 problems, 8 best runs:
#   - Best average hard loss: 5617434.1250
#   - Final average soft loss: 5617888.9688
#   - Final average hard loss: 5617489.3750
#   - Problems included: bur26b.dat, bur26h.dat, bur26c.dat, bur26a.dat, bur26f.dat, bur26d.dat, bur26e.dat, bur26g.dat

# %%
results = read_loss_curves_from_json('train_be/loss_curves_pgd+k+5_real_100_random_20250730_014342.json')
plot_average_loss_curves_across_problems(results, normalize=False)
# Out:
# Summary across 8 problems, 8 best runs:
#   - Best average hard loss: 5697041.5000
#   - Final average soft loss: 5703833.2812
#   - Final average hard loss: 5701184.1250
#   - Problems included: bur26b.dat, bur26h.dat, bur26c.dat, bur26a.dat, bur26f.dat, bur26d.dat, bur26e.dat, bur26g.dat

# %%
results = read_loss_curves_from_json('train_be/loss_curves_gd+k+5_real_None_random_20250730_100252.json')
plot_average_loss_curves_across_problems(results, normalize=False)
# Out:
# Summary across 8 problems, 8 best runs:
#   - Best average hard loss: 5690109.8750
#   - Final average soft loss: 5692954.8438
#   - Final average hard loss: 5690109.8750
#   - Problems included: bur26b.dat, bur26h.dat, bur26c.dat, bur26a.dat, bur26f.dat, bur26d.dat, bur26e.dat, bur26g.dat
